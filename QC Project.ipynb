# %% [markdown]
# ***Simulation and Measurement of Three-Qubit Quantum States! ⚡***

# %%
# !git config --global user.name "Zohrae"

# %%
# !git config --global user.email "zahraelamssane@gmail.com"

# %%
# !git clone https://github.com/Zohrae/QC-project.git
# %cd QC-project
# Out:
# Cloning into 'QC-project'...
# ...
# /content/QC-project

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/QC Project.ipynb" .
# Out:
# cp: missing destination file operand after '/content/drive/MyDrive/Colab Notebooks/QC Project.ipynb'
# Try 'cp --help' for more information.

# %%
# !git add "QC Project.ipynb"
# Out:
# fatal: pathspec 'QC Project.ipynb' did not match any files
